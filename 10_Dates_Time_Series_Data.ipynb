# %%
# Importing pandas library and loading data
import pandas as pd
import numpy as np
df = pd.read_csv(r"C:\Users\battih\Downloads\ETH_1h.csv")

# %%
df.shape
# Out:
# (23674, 7)

# %%
df.head()
# Out:
#                Date  Symbol    Open    High     Low   Close      Volume
# 0  2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1  2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2  2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3  2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4  2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %%
df.info() # The date column is not in datetime format
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23674 entries, 0 to 23673
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    23674 non-null  object
#  1   Symbol  23674 non-null  object
#  2   Open    23674 non-null  float64
#  3   High    23674 non-null  float64
#  4   Low     23674 non-null  float64
#  5   Close   23674 non-null  float64
#  6   Volume  23674 non-null  float64
# dtypes: float64(5), object(2)
# memory usage: 1.3+ MB

# %%
df['Date'] = pd.to_datetime(df['Date'])
# Out:
# C:\Users\battih\AppData\Local\Temp\ipykernel_52868\2394721818.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date'] = pd.to_datetime(df['Date'])
# ---------------------------------------------------------------------------
# DateParseError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df['Date'] = pd.to_datetime(df['Date'])
#
# File c:\Users\battih\Desktop\Personal\Python\Pandas_by_CoreySchafer\myenv\Lib\site-packages\pandas\core\tools\datetimes.py:1067, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1065         result = arg.map(cache_array)
#    1066     else:
# -> 1067         values = convert_listlike(arg._values, format)
#    1068         result = arg._constructor(values, index=arg.index, name=arg.name)
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'],format='%Y-%m-%d %I-%p')

# %%
df['Date']
# Out:
# 0       2020-03-13 20:00:00
# 1       2020-03-13 19:00:00
# 2       2020-03-13 18:00:00
# 3       2020-03-13 17:00:00
# 4       2020-03-13 16:00:00
#                 ...
# 23669   2017-07-01 15:00:00
# 23670   2017-07-01 14:00:00
# 23671   2017-07-01 13:00:00
# 23672   2017-07-01 12:00:00
# 23673   2017-07-01 11:00:00
# Name: Date, Length: 23674, dtype: datetime64[ns]

# %%
df.loc[0,'Date'].day_name()
# Out:
# 'Friday'

# %%
df['Date'].dt.day_name()
# Out:
# 0          Friday
# 1          Friday
# 2          Friday
# 3          Friday
# 4          Friday
#            ...
# 23669    Saturday
# 23670    Saturday
# 23671    Saturday
# 23672    Saturday
# 23673    Saturday
# Name: Date, Length: 23674, dtype: object

# %%
# Add a column with day name
df['DayOfWeek'] = df['Date'].dt.day_name()

# %%
df
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#       DayOfWeek
# ...

# %%
df['Date'].min()
# Out:
# Timestamp('2017-07-01 11:00:00')

# %%
df['Date'].max()
# Out:
# Timestamp('2020-03-13 20:00:00')

# %%
# Difference between two date
df['Date'].max() - df['Date'].min()
# Out:
# Timedelta('986 days 09:00:00')

# %%
filt = (df['Date']>'2019-04-8')
df.loc[filt]
# Out:
#                     Date  Symbol    Open    High     Low   Close      Volume  \
# 0    2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1    2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2    2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3    2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4    2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                  ...     ...     ...     ...     ...     ...         ...
# 8175 2019-04-08 05:00:00  ETHUSD  185.32  185.70  182.29  184.01  1233682.52
# 8176 2019-04-08 04:00:00  ETHUSD  181.43  185.61  181.43  185.32  1396260.40
# 8177 2019-04-08 03:00:00  ETHUSD  182.50  183.55  180.50  181.43  2556876.58
# 8178 2019-04-08 02:00:00  ETHUSD  183.39  187.62  181.38  182.50  4825562.13
# 8179 2019-04-08 01:00:00  ETHUSD  184.12  185.69  181.86  183.39  4125046.42
#
#      DayOfWeek
# 0       Friday
# ...

# %%
filt = ((df['Date']>pd.to_datetime('2019-01-01')) & (df['Date']<pd.to_datetime('2019-01-02')))
df.loc[filt]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 10485 2019-01-01 23:00:00  ETHUSD  137.98  140.90  137.20  139.75  2267514.08
# 10486 2019-01-01 22:00:00  ETHUSD  137.71  138.24  136.66  137.98   840857.18
# 10487 2019-01-01 21:00:00  ETHUSD  138.21  138.79  137.68  137.71  1156494.44
# 10488 2019-01-01 20:00:00  ETHUSD  136.00  140.45  135.83  138.21  3326711.79
# 10489 2019-01-01 19:00:00  ETHUSD  132.34  136.18  132.34  136.00  1043670.71
# 10490 2019-01-01 18:00:00  ETHUSD  133.10  133.10  131.49  132.34  1382653.37
# 10491 2019-01-01 17:00:00  ETHUSD  133.36  133.75  133.04  133.10   511163.36
# 10492 2019-01-01 16:00:00  ETHUSD  133.06  133.50  132.80  133.36   543086.42
# 10493 2019-01-01 15:00:00  ETHUSD  133.81  133.81  132.80  133.06   540296.67
# 10494 2019-01-01 14:00:00  ETHUSD  134.65  134.65  133.80  133.81   806604.71
# 10495 2019-01-01 13:00:00  ETHUSD  134.45  135.20  134.01  134.65   228495.20
# ...

# %%
df.set_index('Date',inplace=True)

# %%
df = df.sort_index()
df.loc['2020-02':'2020-03']
df['2020-02':'2020-03']
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-02-01 00:00:00  ETHUSD  179.74  181.41  179.00  181.06   637332.52
# 2020-02-01 01:00:00  ETHUSD  181.06  183.64  180.98  183.59   946295.21
# 2020-02-01 02:00:00  ETHUSD  183.59  184.00  181.93  183.61  1829192.09
# 2020-02-01 03:00:00  ETHUSD  183.61  183.81  182.41  183.16   279177.55
# 2020-02-01 04:00:00  ETHUSD  183.16  183.49  181.34  181.74   706490.86
# ...                     ...     ...     ...     ...     ...         ...
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
#
#                     DayOfWeek
# Date
# 2020-02-01 00:00:00  Saturday
# ...

# %%
df.loc['2020-01':'2020-02']['Close'].median()
# Out:
# np.float64(179.14499999999998)

# %%
df.loc['2020-01-01']['High'].max()
# Out:
# np.float64(132.68)

# %%
df['High'].resample('D').max().reset_index()
# Out:
#           Date    High
# 0   2017-07-01  279.99
# 1   2017-07-02  293.73
# 2   2017-07-03  285.00
# 3   2017-07-04  282.83
# 4   2017-07-05  274.97
# ..         ...     ...
# 982 2020-03-09  208.65
# 983 2020-03-10  206.28
# 984 2020-03-11  202.98
# 985 2020-03-12  195.64
# 986 2020-03-13  148.00
#
# [987 rows x 2 columns]

# %%
highs = df['High'].resample('D').max()
highs['2020-01-01']
# Out:
# np.float64(132.68)

# %%
# %matplotlib inline
highs.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df[['Open', 'High', 'Low', 'Close', 'Volume']].resample('W').mean()
# Out:
#                   Open        High         Low       Close        Volume
# Date
# 2017-07-02  268.066486  271.124595  264.819730  268.202162  2.185035e+06
# 2017-07-09  261.337024  262.872917  259.186190  261.062083  1.337349e+06
# 2017-07-16  196.193214  199.204405  192.722321  195.698393  2.986756e+06
# 2017-07-23  212.351429  215.779286  209.126310  212.783750  4.298593e+06
# 2017-07-30  203.496190  205.110357  201.714048  203.309524  1.581729e+06
# ...                ...         ...         ...         ...           ...
# 2020-02-16  255.021667  257.255238  252.679762  255.198452  2.329087e+06
# 2020-02-23  265.220833  267.263690  262.948512  265.321905  1.826094e+06
# 2020-03-01  236.720536  238.697500  234.208750  236.373988  2.198762e+06
# 2020-03-08  229.923571  231.284583  228.373810  229.817619  1.628910e+06
# 2020-03-15  176.937521  179.979487  172.936239  176.332821  4.259828e+06
#
# [142 rows x 5 columns]

# %%
df_new = df[['Open', 'High', 'Low', 'Close', 'Volume']].resample('W').agg({'Close':'mean','High':'max','Low':'min','Volume':'sum'})

# %%
df_new.d
# Out:
#                  Close    High     Low        Volume
# Date
# 2017-07-02  268.202162  293.73  253.23  8.084631e+07
# 2017-07-09  261.062083  285.00  231.25  2.246746e+08
# 2017-07-16  195.698393  240.33  130.26  5.017750e+08
# 2017-07-23  212.783750  249.40  153.25  7.221637e+08
# 2017-07-30  203.309524  229.99  178.03  2.657305e+08
# ...                ...     ...     ...           ...
# 2020-02-16  255.198452  290.00  216.31  3.912867e+08
# 2020-02-23  265.321905  287.13  242.36  3.067838e+08
# 2020-03-01  236.373988  278.13  209.26  3.693920e+08
# 2020-03-08  229.817619  253.01  196.00  2.736569e+08
# 2020-03-15  176.332821  208.65   90.00  4.983998e+08
#
# [142 rows x 4 columns]

# %%
df_new.drop(['Volume'],axis=1).plot()
# Out:
# <Axes: xlabel='Date'>
